# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url='https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'
fuel = pd.read_csv(url, error_bad_lines=False)
fuel.describe(include='all')
# Out:
#                       record_id  utility_id_ferc1   report_year  \
# count                     29523      29523.000000  29523.000000
# unique                    29523               NaN           NaN
# top     f1_fuel_2014_12_177_2_4               NaN           NaN
# freq                          1               NaN           NaN
# mean                        NaN        118.601836   2005.806050
# std                         NaN         74.178353      7.025483
# min                         NaN          1.000000   1994.000000
# 25%                         NaN         55.000000   2000.000000
# 50%                         NaN        122.000000   2006.000000
# 75%                         NaN        176.000000   2012.000000
# max                         NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
fuel.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
fuel.dtypes
# Out:
# record_id                        object
# utility_id_ferc1                  int64
# report_year                       int64
# plant_name_ferc1                 object
# fuel_type_code_pudl              object
# fuel_unit                        object
# fuel_qty_burned                 float64
# fuel_mmbtu_per_unit             float64
# fuel_cost_per_unit_burned       float64
# fuel_cost_per_unit_delivered    float64
# fuel_cost_per_mmbtu             float64
# dtype: object

# %%
fuel.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel.isnull().sum() / fuel.isnull().count() * 100
# Out:
# record_id                       0.000000
# utility_id_ferc1                0.000000
# report_year                     0.000000
# plant_name_ferc1                0.000000
# fuel_type_code_pudl             0.000000
# fuel_unit                       0.609694
# fuel_qty_burned                 0.000000
# fuel_mmbtu_per_unit             0.000000
# fuel_cost_per_unit_burned       0.000000
# fuel_cost_per_unit_delivered    0.000000
# fuel_cost_per_mmbtu             0.000000
# dtype: float64

# %%
fuel.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fuel['fuel_unit'].fillna(fuel['fuel_unit'].mode()[0], inplace = True)

# %%
fuel.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel.head(10)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
# 5  f1_fuel_1994_12_2_0_13                 2         1994
# 6   f1_fuel_1994_12_2_1_1                 2         1994
# 7  f1_fuel_1994_12_2_1_10                 2         1994
# 8  f1_fuel_1994_12_2_2_10                 2         1994
# 9   f1_fuel_1994_12_4_0_1                 4         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# ...

# %%
fuel.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11534
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fuel.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
np.unique(fuel['fuel_type_code_pudl'])
# Out:
# array(['coal', 'gas', 'nuclear', 'oil', 'other', 'waste'], dtype=object)

# %%
fuel.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
fuel['fuel_cost_per_unit_burned']
# Out:
# 0        18.59
# 1        18.58
# 2        39.72
# 3        47.21
# 4         2.77
#          ...
# 29518     4.78
# 29519     3.65
# 29520     4.77
# 29521     3.06
# 29522     0.00
# Name: fuel_cost_per_unit_burned, Length: 29523, dtype: float64

# %%
max_fuel_cost1 = fuel['fuel_cost_per_unit_delivered'].reset_index(drop=True)
max_fuel_cost2 = fuel['report_year'].reset_index(drop=True)
assert len(fuel) == len(max_fuel_cost1) + len(max_fuel_cost2)
pd.merge(max_fuel_cost1, max_fuel_cost2, how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-42-87e0af6effcb> in <module>
#       1 max_fuel_cost1 = fuel['fuel_cost_per_unit_delivered'].reset_index(drop=True)
#       2 max_fuel_cost2 = fuel['report_year'].reset_index(drop=True)
# ----> 3 assert len(fuel) == len(max_fuel_cost1) + len(max_fuel_cost2)
#       4 pd.merge(max_fuel_cost1, max_fuel_cost2, how = 'inner')
#
# AssertionError:

# %%
fuel[['fuel_cost_per_unit_delivered','report_year']].groupby(['report_year']).mean()
# Out:
#              fuel_cost_per_unit_delivered
# report_year
# 1994                            63.636060
# 1995                            32.735269
# 1996                          9196.705948
# 1997                         11140.197239
# 1998                           287.154420
# 1999                            25.551627
# 2000                           985.362877
# 2001                            60.050396
# 2002                            47.594361
# 2003                            55.663493
# 2004                           139.524275
# 2005                            41.438184
# 2006                            38.657484
# 2007                            43.325023
# 2008                            58.588197
# 2009                           652.694163
# 2010                            91.862105
# 2011                            59.774667
# 2012                            60.994502
# 2013                           172.307591
# 2014                           192.737183
# ...

# %%
fuel[['fuel_cost_per_unit_burned','report_year']].groupby(['report_year']).sum()
# Out:
#              fuel_cost_per_unit_burned
# report_year
# 1994                        263292.115
# 1995                        425661.488
# 1996                         86425.275
# 1997                        163533.452
# 1998                        140238.656
# 1999                        126056.285
# 2000                        326495.434
# 2001                        180365.641
# 2002                        121921.135
# 2003                        149175.726
# 2004                        184637.699
# 2005                        135924.139
# 2006                        188142.032
# 2007                        256114.312
# 2008                        314312.022
# 2009                        263584.566
# 2010                        331581.467
# 2011                        374175.603
# 2012                        321693.544
# 2013                        306933.236
# 2014                        518002.469
# 2015                        260060.984
# 2016                        255484.814
# ...
